# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.scatter(1,1) #n'accepte pas le 3ème param (color)
plt.plot(1,3,"ro")
plt.plot(2,5,"bo")

# %%
plt.plot([1,-5,-1],[1,5,6])

# %%
def f(x):
    return x**2

x=np.array([1,2,3])
y=f(x)

# %%
plt.plot(x,y)

# %%
x=np.arange(-10,10,0.1)
y=f(x)
plt.plot(x,y)
plt.plot(-7,f(-7),"ro")
plt.plot(-7,f(7),"ro")
